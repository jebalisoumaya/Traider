# %%
# =============================
# 1) Imports & config
# =============================
# %pip install tensorflow numpy matplotlib tqdm --upgrade --quiet

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
import matplotlib.pyplot as plt
from collections import deque
from tqdm import tqdm

np.set_printoptions(suppress=True)
print("✅ TensorFlow :", tf.__version__)

# =============================
# 2) Chargement des données
# =============================
print("📦 Chargement btc_dataset_for_agent.npz ...")
data = np.load("btc_dataset_for_agent.npz", allow_pickle=True)
features = data["features"].astype(np.float32)   # (N, d_f)
signals  = data["signals"].astype(np.float32)    # (N, d_s)
prices   = data["prices"].astype(np.float32).squeeze()  # (N,)

pos_dim   = 1
base_dim  = features.shape[1] + signals.shape[1] + pos_dim
n_actions = 3  # 0=Hold, 1=Buy, 2=Sell

split = int(0.8 * len(prices))
Xf_train, Xf_test = features[:split], features[split:]
Xs_train, Xs_test = signals[:split],  signals[split:]
P_train,  P_test  = prices[:split],   prices[split:]

print(f"✅ Données : features {features.shape}, signals {signals.shape}, prices {prices.shape}")
print(f"🔧 Split -> Train: {len(P_train)} | Test: {len(P_test)}")

# =============================
# 3) Environnement avec fenêtre (seq_len)
# =============================
class TradingEnv:
    """
    Actions: 0=Hold, 1=Long, 2=Short
    Reward = 100 * ( position * Δlog(P) - coût de turnover ) - hold_penalty
    Observation = fenêtre séquentielle (seq_len x state_dim) : [features | signals | position]
    """
    def __init__(self, features, signals, prices, seq_len=16, fee_bps=0.0005, reward_scale=100.0, hold_penalty=0.01):
        self.features = features.astype(np.float32)
        self.signals  = signals.astype(np.float32)
        self.prices   = prices.astype(np.float32).squeeze()
        self.seq_len  = int(seq_len)
        self.fee_bps  = float(fee_bps)
        self.scale    = float(reward_scale)
        self.hold_penalty = float(hold_penalty)

        # rendements log pour la reward
        self.logp = np.log(np.clip(self.prices, 1e-6, None))
        self.reset()

    def _state_now(self):
        vec = np.concatenate([self.features[self.t], self.signals[self.t], np.array([self.position], np.float32)], axis=-1)
        return vec

    def _obs_from_buffer(self):
        # (seq_len, state_dim)
        arr = np.array(self.buffer, dtype=np.float32)
        return arr

    def reset(self):
        self.t = 0
        self.position = 0  # -1,0,+1
        self.pnl = 0.0     # en %
        self.buffer = deque(maxlen=self.seq_len)
        # initialiser la fenêtre avec des états neutres (position=0)
        for k in range(self.seq_len):
            self.buffer.append(self._state_now())
            if self.t < len(self.prices) - 1:
                self.t += 1
        return self._obs_from_buffer()

    def step(self, action:int):
        prev_pos = self.position
        if action == 1:   self.position = 1
        elif action == 2: self.position = -1
        else:             self.position = 0

        reward = 0.0
        if self.t < len(self.prices) - 1:
            dlog = float(self.logp[self.t + 1] - self.logp[self.t])
            turnover_cost = self.fee_bps * abs(self.position - prev_pos)
            reward = (self.position * dlog - turnover_cost) * self.scale
            if action == 0:
                reward -= self.hold_penalty  # décourage inaction systématique
            # pnl en %
            self.pnl += (self.position * dlog - turnover_cost)

        # avancer le temps et rafraîchir la fenêtre
        self.buffer.append(self._state_now())
        self.t += 1
        done = self.t >= (len(self.prices) - 2)
        next_obs = None if done else self._obs_from_buffer()
        return next_obs, float(reward), bool(done)

# instancier
SEQ_LEN = 16
env_train = TradingEnv(Xf_train, Xs_train, P_train, seq_len=SEQ_LEN, hold_penalty=0.01)
env_test  = TradingEnv(Xf_test,  Xs_test,  P_test,  seq_len=SEQ_LEN, hold_penalty=0.00)

state_dim = base_dim  # par pas
print(f"🧩 Observation : (seq_len={SEQ_LEN}, state_dim={state_dim})")

# =============================
# 4) DARQN (LSTM + Dueling) TF
# =============================

tf.keras.mixed_precision.set_global_policy("float32")


def build_darqn(input_dim, n_actions, hidden=128, seq_len=16):
    inp = layers.Input(shape=(seq_len, input_dim))
    x = layers.TimeDistributed(layers.Dense(hidden, activation='relu'))(inp)
    x = layers.LSTM(hidden, return_sequences=False)(x)

    # --- Dueling head (en Lambda pour éviter l’erreur) ---
    val = layers.Dense(64, activation='relu')(x)
    val = layers.Dense(1, name="value")(val)                          # (B,1)

    adv = layers.Dense(64, activation='relu')(x)
    adv = layers.Dense(n_actions, name="advantage")(adv)              # (B,nA)

    # Centrage de l’avantage: adv - mean(adv, axis=1, keepdims=True)
    adv_mean = layers.Lambda(lambda a: tf.reduce_mean(a, axis=1, keepdims=True),
                             name="adv_mean")(adv)
    adv_centered = layers.Subtract(name="adv_centered")([adv, adv_mean])

    # Q(s,a) = V(s) + A(s,a)
    q = layers.Add(name="q_values")([val, adv_centered])              # broadcasting (B,1) + (B,nA)

    model = models.Model(inp, q, name="DARQN")
    return model

qnet = build_darqn(state_dim, n_actions, hidden=128, seq_len=SEQ_LEN)
tgt  = build_darqn(state_dim, n_actions, hidden=128, seq_len=SEQ_LEN)
tgt.set_weights(qnet.get_weights())
qnet.summary()

opt = optimizers.Adam(1e-4)
loss_fn = tf.keras.losses.Huber()

# =============================
# 5) Replay Buffer simple
# =============================
class ReplayBuffer:
    def __init__(self, capacity=20000):
        self.S  = deque(maxlen=capacity)
        self.SN = deque(maxlen=capacity)
        self.A  = deque(maxlen=capacity)
        self.R  = deque(maxlen=capacity)
        self.D  = deque(maxlen=capacity)

    def add(self, s, a, r, sn, d):
        self.S.append(s); self.A.append(a); self.R.append(r); self.SN.append(sn); self.D.append(d)

    def sample(self, batch):
        idx = np.random.choice(len(self.S), batch, replace=False)
        S  = np.array([self.S[i]  for i in idx], dtype=np.float32)
        SN = np.array([self.SN[i] for i in idx], dtype=np.float32)
        A  = np.array([self.A[i]  for i in idx], dtype=np.int32)
        R  = np.array([self.R[i]  for i in idx], dtype=np.float32)
        D  = np.array([self.D[i]  for i in idx], dtype=np.float32)
        return S, A, R, SN, D

buffer = ReplayBuffer(20000)

# =============================
# 6) Hyperparamètres RL
# =============================
gamma         = 0.99
epsilon       = 1.0
epsilon_min   = 0.05
epsilon_decay = 0.997
tau           = 0.01         # soft update cible
batch_size    = 64
update_every  = 32
warmup        = 512          # transitions avant premiers updates
episodes      = 60

print("\n🚀 Entraînement sur TRAIN ...\n")
for ep in range(episodes):
    s = env_train.reset()
    done = False
    total_R = 0.0
    step = 0

    while not done:
        # ε-greedy
        if np.random.rand() < epsilon:
            a = np.random.randint(0, n_actions)
        else:
            q = qnet.predict(s[np.newaxis, :], verbose=0)[0]
            a = int(np.argmax(q))

        sn, r, done = env_train.step(a)
        if sn is not None:
            buffer.add(s, a, r, sn, float(done))
            s = sn

        total_R += r
        step += 1

        # updates fréquents
        if len(buffer.S) >= max(batch_size, warmup) and (step % update_every == 0):
            S, A, R, SN, D = buffer.sample(batch_size)

            with tf.GradientTape() as tape:
                Q     = qnet(S, training=True)                                # (B, nA)
                Q_sel = tf.gather_nd(Q, tf.stack([tf.range(batch_size), A], axis=1))

                Qnext = tgt(SN, training=False)
                maxQn = tf.reduce_max(Qnext, axis=1)
                target= R + gamma * maxQn * (1.0 - D)

                loss  = loss_fn(target, Q_sel)

            grads = tape.gradient(loss, qnet.trainable_variables)
            opt.apply_gradients(zip(grads, qnet.trainable_variables))

            # soft update du réseau cible
            for tp, p in zip(tgt.variables, qnet.variables):
                tp.assign(tau * p + (1.0 - tau) * tp)

    epsilon = max(epsilon * epsilon_decay, epsilon_min)
    print(f"Épisode {ep+1}/{episodes} — Récompense totale (TRAIN) : {total_R:.3f} — ε={epsilon:.3f}")

print("\n✅ Entraînement terminé.")

# =============================
# 7) Test (greedy) sur TEST
# =============================
print("\n🔍 Phase de TEST ...\n")
s = env_test.reset()
done = False
actions, rewards, pnls = [], [], []

while not done:
    q = qnet.predict(s[np.newaxis, :], verbose=0)[0]
    a = int(np.argmax(q))
    sn, r, done = env_test.step(a)
    actions.append(a); rewards.append(r); pnls.append(env_test.pnl)
    if sn is not None: s = sn

print("✅ Test terminé.")

# =============================
# 8) Visualisations & métriques
# =============================
plt.figure(figsize=(12,6))
plt.plot(P_test, label='Prix BTC (TEST)', alpha=0.7)
buy  = [i for i,a in enumerate(actions) if a==1]
sell = [i for i,a in enumerate(actions) if a==2]
if buy:  plt.scatter(buy,  P_test[buy],  color='green', marker='^', label='Achat')
if sell: plt.scatter(sell, P_test[sell], color='red',   marker='v', label='Vente')
plt.title("Décisions de l’agent — TEST")
plt.legend(); plt.show()

plt.figure(figsize=(10,4))
plt.plot(np.array(pnls)*100, color='orange', label='PnL cumulé (%)')
plt.title("Profit net cumulé — TEST"); plt.legend(); plt.show()

R = np.array(rewards, np.float32)
pnl_total_pct = float(pnls[-1])*100 if len(pnls) else 0.0
sharpe = float(R.mean() / (R.std() + 1e-8))
win = float((R > 0).mean())*100.0

print("\n📊 Évaluation finale (TEST)")
print(f"💰 PnL total : {pnl_total_pct:.2f}%")
print(f"⚖️ Sharpe : {sharpe:.4f}")
print(f"🏆 Taux de succès : {win:.2f}%")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ✅ TensorFlow : 2.20.0-rc0
# 📦 Chargement btc_dataset_for_agent.npz ...
# ✅ Données : features (1367, 5), signals (1367, 2), prices (1367,)
# 🔧 Split -> Train: 1093 | Test: 274
# 🧩 Observation : (seq_len=16, state_dim=8)
# WARNING:tensorflow:From C:\Users\Admin\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "DARQN"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 16, 8)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_2  │ (None, 16, 128)   │      1,152 │ input_layer_2[0]… │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 128)       │    131,584 │ time_distributed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 64)        │      8,256 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ advantage (Dense)   │ (None, 3)         │        195 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 64)        │      8,256 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adv_mean (Lambda)   │ (None, 1)         │          0 │ advantage[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ value (Dense)       │ (None, 1)         │         65 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adv_centered        │ (None, 3)         │          0 │ advantage[0][0],  │
# │ (Subtract)          │                   │            │ adv_mean[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ q_values (Add)      │ (None, 3)         │          0 │ value[0][0],      │
# │                     │                   │            │ adv_centered[0][… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 149,508 (584.02 KB)
#  Trainable params: 149,508 (584.02 KB)
#  Non-trainable params: 0 (0.00 B)
# 🚀 Entraînement sur TRAIN ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_113072\4051700021.py in ?()
#     211         if len(buffer.S) >= max(batch_size, warmup) and (step % update_every == 0):
#     212             S, A, R, SN, D = buffer.sample(batch_size)
#     213
#     214             with tf.GradientTape() as tape:
# --> 215                 Q     = qnet(S, training=True)                                # (B, nA)
#     216                 Q_sel = tf.gather_nd(Q, tf.stack([tf.range(batch_size), A], axis=1))
#     217
#     218                 Qnext = tgt(SN, training=False)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\models\functional.py in ?(self, inputs, training, mask, **kwargs)
#     179             masks = tree.flatten(mask)
#     180             for x, mask in zip(inputs, masks):
#     181                 if mask is not None:
#     182                     backend.set_keras_mask(x, mask)
# --> 183         outputs = self._run_through_graph(
#     184             inputs,
#     185             operation_fn=lambda op: operation_fn(
#     186                 op, training=training, **kwargs
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\ops\function.py in ?(self, inputs, operation_fn, call_fn)
#     202                 else:
#     203                     # Use NNX operation mapping
#     204                     operation = self._get_operation_for_node(node)
#     205                     op = operation_fn(operation)
# --> 206                     outputs = op(*args, **kwargs)
#     207
#     208                 # Update tensor_dict.
#     209                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\models\functional.py in ?(*args, **kwargs)
#     640                 and value is not None
#     641             ):
#     642                 kwargs[name] = value
#     643
# --> 644         return operation(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\lstm.py in ?(self, sequences, initial_state, mask, training)
#     582     def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 583         return super().call(
#     584             sequences, mask=mask, training=training, initial_state=initial_state
#     585         )
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py in ?(self, sequences, initial_state, mask, training)
#     402         self._maybe_config_dropout_masks(
#     403             self.cell, sequences[:, 0, :], initial_state
#     404         )
#     405
# --> 406         last_output, outputs, states = self.inner_loop(
#     407             sequences=sequences,
#     408             initial_state=initial_state,
#     409             mask=mask,
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\lstm.py in ?(self, sequences, initial_state, mask, training)
#     574                 "but cuDNN is not supported for this layer configuration "
#     575                 "with this backend. Pass use_cudnn='auto' to fallback "
#     576                 "to a non-cuDNN implementation."
#     577             )
# --> 578         return super().inner_loop(
#     579             sequences, initial_state, mask=mask, training=training
#     580         )
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py in ?(self, sequences, initial_state, mask, training)
#     342
#     343         if not tree.is_nested(initial_state):
#     344             initial_state = [initial_state]
#     345
# --> 346         return backend.rnn(
#     347             step,
#     348             sequences,
#     349             initial_state,
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\rnn.py in ?(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     424                     initial_states, flat_new_state
#     425                 )
#     426                 return (time + 1, output_ta_t) + tuple(new_states)
#     427
# --> 428             final_outputs = tf.while_loop(
#     429                 body=_step,
#     430                 loop_vars=(time, output_ta) + states,
#     431                 **while_loop_kwargs,
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\deprecation.py in ?(*args, **kwargs)
#     656                   _call_location(), decorator_utils.get_qualified_name(func),
#     657                   func.__module__, arg_name, arg_value,
#     658                   'in a future version' if date is None else
#     659                   ('after %s' % date), instructions)
# --> 660       return func(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#     237   ...   print(sess.run(x_out).shape)
#     238   (1000, 100)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     484
#     485       loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                               list(loop_vars))
#     487       while cond(*loop_vars):
# --> 488         loop_vars = body(*loop_vars)
#     489         if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490           packed = True
#     491           loop_vars = (loop_vars,)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\while_loop.py in ?(i, lv)
# --> 479         body = lambda i, lv: (i + 1, orig_body(*lv))
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\rnn.py in ?(time, output_ta_t, *states)
#     407                     Tuple: `(time + 1,output_ta_t) + tuple(new_states)`
#     408                 """
#     409                 current_input = tuple(ta.read(time) for ta in input_ta)
#     410                 current_input = tree.pack_sequence_as(inputs, current_input)
# --> 411                 output, new_states = step_function(
#     412                     current_input, tuple(states) + tuple(constants)
#     413                 )
#     414                 flat_new_state = tree.flatten(new_states)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py in ?(inputs, states)
#     334             # that would otherwise break PyTorch's autograd functionality
#     335             # by modifying tensors needed for gradient computation.
#     336             if backend.backend() == "torch" and self.stateful:
#     337                 states = tree.map_structure(ops.copy, states)
# --> 338             output, new_states = self.cell(inputs, states, **cell_kwargs)
#     339             if not tree.is_nested(new_states):
#     340                 new_states = [new_states]
#     341             return output, new_states
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\lstm.py in ?(self, inputs, states, training)
#     282
#     283             z = ops.split(z, 4, axis=1)
#     284             c, o = self._compute_carry_and_output_fused(z, c_tm1)
#     285
# --> 286         h = o * self.activation(c)
#     287         return h, [h, c]
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\activations\activations.py in ?(x)
#     411
#     412     Args:
#     413         x: Input tensor.
#     414     """
# --> 415     return ops.tanh(x)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\ops\numpy.py in ?(x)
#    5887         Output tensor of same shape as `x`.
#    5888     """
#    5889     if any_symbolic_tensors((x,)):
#    5890         return Tanh().symbolic_call(x)
# -> 5891     return backend.numpy.tanh(x)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\sparse.py in ?(x, *args, **kwargs)
#     383             return tf.IndexedSlices(
#     384                 func(x.values, *args, **kwargs), x.indices, x.dense_shape
#     385             )
#     386         else:
# --> 387             return func(x, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\numpy.py in ?(x)
#    2438         dtype = config.floatx()
#    2439     else:
#    2440         dtype = dtypes.result_type(x.dtype, float)
#    2441     x = tf.cast(x, dtype)
# -> 2442     return tf.math.tanh(x)
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#      91     bound_kwargs = bound_arguments.arguments
#
# ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, name)
#   12545         _ctx, "Tanh", name, x)
#   12546       return _result
#   12547     except _core._NotOkStatusException as e:
#   12548       _ops.raise_from_not_ok_status(e, name)
# > 12549     except _core._FallbackException:
#   12550       pass
#   12551     try:
#   12552       _result = _dispatcher_for_tanh(
#
# KeyboardInterrupt:
